# %%
fs=open("/Users/cmdb/qbb2020-answers/Day2/day2-homework/fly.txt", "r")

id_dic = {}
for line in fs:
    if "DROME" not in line:
        continue
        
    else:
        fields = line.split()
        gene_id = fields[-1]
        uniprot_id = fields[-2]
        
        id_dic[gene_id]=uniprot_id

id_dic
# Out:
# {'FBgn0010339': 'P32234',
#  'FBgn0020238': 'P92177',
#  'FBgn0004907': 'P29310',
#  'FBgn0010340': 'P81928',
#  'FBgn0027624': 'P04283',
#  'FBgn0044339': 'P04282',
#  'FBgn0014453': 'P04323',
#  'FBgn0027623': 'P20829',
#  'FBgn0044338': 'P20828',
#  'FBgn0027622': 'P20825',
#  'FBgn0043847': 'P10394',
#  'FBgn0004168': 'P28285',
#  'FBgn0263116': 'P28286',
#  'FBgn0004573': 'P20905',
#  'FBgn0011294': 'P54185',
#  'FBgn0023130': 'O46341',
#  'FBgn0011293': 'Q27377',
#  'FBgn0027885': 'Q9V431',
#  'FBgn0019643': 'Q94521',
#  'FBgn0027780': 'Q9VLL0',
#  'FBgn0031851': 'Q9VM95',
#  'FBgn0023129': 'Q9VSY6',
#  'FBgn0264442': 'Q24174',
#  'FBgn0039890': 'Q7JUN3',
#  'FBgn0000014': 'P29555',
#  'FBgn0000015': 'P09087',
#  'FBgn0000017': 'P00522',
#  'FBgn0036372': 'Q9VU84',
#  'FBgn0015331': 'Q9V3C0',
#  'FBgn0000022': 'P10083',
#  'FBgn0004852': 'Q9VW60',
#  'FBgn0024150': 'Q9VP76',
#  'FBgn0011273': 'P49258',
#  'FBgn0010387': 'P42281',
#  'FBgn0012034': 'Q9VP61',
# ...

# %%
ct = open("/Users/cmdb/data/results/t_data.ctab", "r")


def my_function(arg1, arg2, arg3):

    new_list=[]
    count=0
    for line in arg1:
        fields = line.rstrip("\n\r").split()
        gene_id_ct = fields[8]
    
        if gene_id_ct in arg2:
            count = count +1
            new_list.append(str(fields[1:8]) + id_dic[gene_id_ct] + str(fields[9:]))
        elif arg3 == "ignore":
            continue
            else:
                new_list.append(str(fields[1:8]) + arg3 + str(fields[9:]))
        #This is printing all of the things that I want as a line, but not really in the format that I want
        
        print(new_list)
    
#my_function(ct, id_dic, ignore)
# Out:
#   File "<ipython-input-58-f903611d5637>", line 8
#     for line in arg1:
#     ^
# IndentationError: unexpected indent

# %%
def my_function(arg1, arg2, arg3)

# %%
    else:
        get uniprot_id from gene_id
        
        print fields[1:7] + uniprot_id + fields[8:]

# %%
dic = {"A":1, "B":2}

print(dic["A"])
print(dic.keys())
# Out:
# 1
# dict_keys(['A', 'B'])

# %%
# Out:
#   File "<ipython-input-43-47ceb92eb6b3>", line 6
#     count = +1
#         ^
# IndentationError: expected an indented block
