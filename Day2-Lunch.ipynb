# %%
fs=open("/Users/cmdb/qbb2020/day2/1-morning/fly.txt", "r")

text_file = open("identifiers.txt", "w")

mycol = []

for i in fs:
    if "DROME" in i:
        lines = i.split()
        if len(lines) != 4:
            continue
        mycol= '{}\t{}\n'.format(lines[-1], lines[-2])
        #Hasn't been separated by a "tab", which was requested
        text_file.write(mycol)
            
        print(mycol)
# Out:
# FBgn0010339	P32234
#
# FBgn0020238	P92177
#
# FBgn0004907	P29310
#
# FBgn0010340	P81928
#
# FBgn0027624	P04283
#
# FBgn0044339	P04282
#
# FBgn0014453	P04323
#
# FBgn0027623	P20829
#
# FBgn0044338	P20828
#
# FBgn0027622	P20825
#
# FBgn0043847	P10394
#
# FBgn0004168	P28285
#
# FBgn0263116	P28286
#
# FBgn0004573	P20905
#
# FBgn0011294	P54185
#
# FBgn0023130	O46341
#
# FBgn0011293	Q27377
#
# FBgn0027885	Q9V431
#
# FBgn0019643	Q94521
#
# FBgn0027780	Q9VLL0
#
# FBgn0031851	Q9VM95
#
# FBgn0023129	Q9VSY6
#
# FBgn0264442	Q24174
#
# FBgn0039890	Q7JUN3
#
# FBgn0000014	P29555
#
# FBgn0000015	P09087
#
# FBgn0000017	P00522
#
# FBgn0036372	Q9VU84
#
# FBgn0015331	Q9V3C0
#
# FBgn0000022	P10083
#
# FBgn0004852	Q9VW60
#
# FBgn0024150	Q9VP76
#
# FBgn0011273	P49258
#
# FBgn0010387	P42281
#
# FBgn0012034	Q9VP61
#
# FBgn0000024	P07140
#
# FBgn0016122	Q9VLJ6
#
# FBgn0000028	P24350
#
# FBgn0028484	Q9VZI2
#
# FBgn0263998	Q9I7F7
#
# FBgn0014454	Q26416
#
# FBgn0002855	P10333
#
# FBgn0002856	P10334
#
# ...

# %%
# match geneIDs
# then print the ctab line

ct = open ("/Users/cmdb/data/results/t_data.ctab", "r")

#def compare():
for r in ct:
    row = r.split()
    if str(row[9]) == mycol[0]:
        print(row)
